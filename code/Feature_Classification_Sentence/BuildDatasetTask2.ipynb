# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
import os
import tensorflow as tf 
from google.colab import drive

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

drive.mount("/content/gdrive", force_remount=True)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk import pos_tag, word_tokenize
import numpy as np


sent = "US bloggers banned from entering UK"

def count_tags_sentence(sentence, tag_prefix):
    """
    Counts the number of words in the given sentence
    whose PoS tag matches the given tag_prefix.

    :param string sentence: the sentence to process
    :param string tag_prefix: Penn Treebank tag prefix (e.g. JJ, RB)
    :return: number of words with the tag, matching the tag_prefix
    """
    tags = pos_tag(word_tokenize(sentence.lower()))
    return len(list(filter(lambda tag: tag[1].startswith(tag_prefix), tags)))

def count_adjectives(sentences):
    return list(map(lambda s: [count_tags_sentence(s, tag_prefix='JJ')], sentences))

def count_adverbs(sentences):
    return list(map(lambda s: [count_tags_sentence(s, tag_prefix='RB')], sentences))

def count_singular_pronouns(sentences):
    return list(map(lambda s: [count_tags_sentence(s, tag_prefix='NNP')], sentences))

def count_plural_pronouns(sentences):
    return list(map(lambda s: [count_tags_sentence(s, tag_prefix='NNPS')], sentences))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Found GPU at: /device:GPU:0
# Mounted at /content/gdrive
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def update_dataset(option):
  
  source_dir = '/content/gdrive/My Drive/datathon/train/'
  files = os.listdir(source_dir)
  
  for f in files:
    if f.endswith('.txt'):
      if os.path.isfile('/content/gdrive/My Drive/datathon/train/' + f) and os.path.isfile('/content/gdrive/My Drive/datathon/train/' + f[:-3] + 'task2.labels'):
        with open('/content/gdrive/My Drive/datathon/train/' + f) as f_text, open('/content/gdrive/My Drive/datathon/train/' + f[:-3] + 'task2.labels', 'r') as f_labs:
          lines_f_text = f_text.readlines()
          lines_f_labs = f_labs.readlines()
          for i, l in enumerate(lines_f_text):
            if l == '\n':
              continue
            else:
              if option == "tags":
                n_adj = count_tags_sentence(l[:-1], 'JJ')
                n_adv = count_tags_sentence(l[:-1], 'RB')
                n_singular_pronouns = count_tags_sentence(l[:-1], 'NNP')
                n_plural_pronouns = count_tags_sentence(l[:-1], 'NNPS')
                line_to_write = '\t'.join([str(n) for n in [n_adj, n_adv, n_singular_pronouns, n_plural_pronouns]])
                lines_f_labs[i] = lines_f_labs[i].rstrip() + '\t' + line_to_write + '\n'
                #f_labs_aug.write(lines_f_labs[i][:-1] + '\t' + line_to_write + '\n')

        with open('/content/gdrive/My Drive/datathon/train/' + f[:-3] + 'task2.labels', 'w') as f_labs_2:
          f_labs_2.writelines(lines_f_labs)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-019b5a4031ec> in <module>()
# ----> 1 update_dataset('tags')
#
# <ipython-input-2-ca7462fa5e43> in update_dataset(option)
#       6   for f in files:
#       7     if f.endswith('.txt'):
# ----> 8       with open('/content/gdrive/My Drive/datathon/train/' + f) as f_text, open('/content/gdrive/My Drive/datathon/train/' + f[:-3] + 'task2.labels', 'r') as f_labs:
#       9         lines_f_text = f_text.readlines()
#      10         lines_f_labs = f_labs.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/datathon/train/article771406408.task2.labels'

# %%
# %matplotlib inline

# Import libraries
import pandas as pd
import numpy as np
import os
import re
import glob
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Embedding, LSTM, Bidirectional, GlobalMaxPool1D, Dense, Dropout

from sklearn.metrics import f1_score, confusion_matrix

import glob


def dataprep_task2(path):
    """Dataprep for Task2 It will return the new data
    :param path: Path to the article's taks3 labels file.
    Example:
    >>> dataprep_task2("datasets-v5/tasks-2-3/train/article111111112.task2.labels")
    """
    dir_name = os.path.dirname(path)
    article_id = os.path.basename(path).split('.')[0]
    article_name = os.path.join(dir_name, f'{article_id}.txt')

    with open(article_name, 'r', encoding='utf8') as f:
        records = f.readlines()

    df = pd.DataFrame(records, columns=['sentences'])

    another_df = pd.read_csv(path, sep='\t', names = ['article', 'N_sentence', 'is_propaganda', 'sadness' , 'joy' ,'fear', 'disgust' ,'anger'], encoding='utf8')
    
    result_df = pd.concat([df, another_df], axis=1)
    
    return result_df.loc[result_df['sentences'] != '\n', :]
# Out:
# Using TensorFlow backend.

# %%
df['sentences_prep'] = df['sentences'].apply(clean_text)

# %%
afd = dataprep_task2('/content/gdrive/My Drive/datathon/train/article111111112.task2.labels')

# %%
fileNames = glob.glob('/content/gdrive/My Drive/datathon/train/*.task2.labels')

# %%
afd.head(10)
# Out:
#                                             sentences    article  N_sentence  \
# 0               US bloggers banned from entering UK\n  111111112           1
# 2   Two prominent US bloggers have been banned fro...  111111112           3
# 4   Pamela Geller and Robert Spencer co-founded an...  111111112           5
# 6   They were due to speak at an English Defence L...  111111112           7
# 8   A government spokesman said individuals whose ...  111111112           9
# 10  He added: "We condemn all those whose behaviou...  111111112          11
# 12                                 'Right decision'\n  111111112          13
# 13  Ms Geller, of the Atlas Shrugs blog, and Mr Sp...  111111112          14
# 14  On both of their blogs the pair called their b...  111111112          15
# 16  They were due to attend a march planned by the...  111111112          17
#
#      is_propaganda   sadness       joy      fear   disgust     anger
# 0   non-propaganda  0.273694  0.104768  0.121820  0.378717  0.378898
# 2   non-propaganda  0.322924  0.158435  0.195255  0.267676  0.273668
# 4       propaganda  0.273383  0.068818  0.156252  0.556396  0.241289
# 6   non-propaganda  0.509438  0.087796  0.126802  0.149326  0.254227
# 8   non-propaganda  0.124354  0.568301  0.147631  0.220660  0.084066
# 10      propaganda  0.119858  0.170223  0.072858  0.523191  0.035549
# 12  non-propaganda  0.144572  0.267605  0.123545  0.085044  0.163631
# 13      propaganda  0.350660  0.370516  0.262476  0.128524  0.033058
# 14      propaganda  0.521116  0.037132  0.086949  0.201311  0.495579
# 16  non-propaganda  0.614666  0.028630  0.151450  0.314787  0.107312

# %%
res_list = list()

for f in fileNames:
    res_list.append(dataprep_task2(f))

# %%
df = pd.concat(res_list)

# %%
df.head(10)
# Out:
#                                             sentences    article  N_sentence  \
# 0   New Audio From The Night Of The Las Vegas Mass...  704856340           1
# 2   Newly released audio from the Clark County Fir...  704856340           3
# 3   The audio, released on the SoundCloud account ...  704856340           4
# 4   Intellihub’s Shepard Ambellas, who has extensi...  704856340           5
# 5   “We have a firefighter’s wife at this event wh...  704856340           6
# 6   We are trying to get further on the name,” dis...  704856340           7
# 7   “Batallion 6, be advised that we are getting r...  704856340           8
# 8   After being asked to confirm the information, ...  704856340           9
# 9   “The only information I have is it’s the bar o...  704856340          10
# 10  Interestingly, the story doesn’t end there, as...  704856340          11
#
#      is_propaganda   sadness       joy      fear   disgust     anger
# 0   non-propaganda  0.093891  0.481352  0.238193  0.133129  0.162108
# 2   non-propaganda  0.456951  0.024205  0.162442  0.419307  0.281755
# 3   non-propaganda  0.193504  0.280196  0.125014  0.140594  0.366930
# 4   non-propaganda  0.674633  0.155427  0.046534  0.116447  0.051066
# 5   non-propaganda  0.356464  0.171645  0.098791  0.098959  0.272835
# 6   non-propaganda  0.395951  0.058361  0.141609  0.075802  0.107938
# 7   non-propaganda  0.082155  0.041201  0.110452  0.028624  0.071853
# 8   non-propaganda  0.457318  0.065556  0.055998  0.069855  0.213325
# 9   non-propaganda  0.477513  0.157989  0.067258  0.036316  0.191752
# 10  non-propaganda  0.109102  0.687029  0.089832  0.021488  0.131763

# %%
df['sentences'] = df['sentences'].str.replace('\n', '')

# %%
df.to_csv('/content/gdrive/My Drive/datathon/task2.csv', sep='|||', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-cc5440da40e1> in <module>()
# ----> 1 df.to_csv('/content/gdrive/My Drive/datathon/task2.csv', sep='|||', index=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/format.py in save(self)
#    1648             else:
#    1649                 writer_kwargs['encoding'] = encoding
# -> 1650                 self.writer = UnicodeWriter(f, **writer_kwargs)
#    1651
#    1652             self._save()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/common.py in UnicodeWriter(f, dialect, encoding, **kwds)
#     487
#     488     def UnicodeWriter(f, dialect=csv.excel, encoding="utf-8", **kwds):
# --> 489         return csv.writer(f, dialect=dialect, **kwds)
#     490 else:
#     491     class UnicodeReader(BaseIterator):
#
# TypeError: "delimiter" must be a 1-character string

# %%
df.loc[df['article'] == 111111112]
# Out:
#                                             sentences    article  N_sentence  \
# 0               US bloggers banned from entering UK\n  111111112           1
# 2   Two prominent US bloggers have been banned fro...  111111112           3
# 4   Pamela Geller and Robert Spencer co-founded an...  111111112           5
# 6   They were due to speak at an English Defence L...  111111112           7
# 8   A government spokesman said individuals whose ...  111111112           9
# 10  He added: "We condemn all those whose behaviou...  111111112          11
# 12                                 'Right decision'\n  111111112          13
# 13  Ms Geller, of the Atlas Shrugs blog, and Mr Sp...  111111112          14
# 14  On both of their blogs the pair called their b...  111111112          15
# 16  They were due to attend a march planned by the...  111111112          17
# 18  Keith Vaz, chairman of the Home Affairs Select...  111111112          19
# 19                      This is the right decision.\n  111111112          20
# 20  The UK should never become a stage for inflamm...  111111112          21
# 22  EDL leader Tommy Robinson, meanwhile, criticis...  111111112          23
# 24  "It's embarrassing for this so-called land of ...  111111112          25
# 26  "How many hate preachers are living in this co...  111111112          27
# 27  It just shows what sort of a two-tier system w...  111111112          28
# 29                                  'Foster hatred'\n  111111112          30
# 30  Anti-fascism campaigners Hope Not Hate had cam...  111111112          31
# 32  A researcher with the organisation, Matthew Co...  111111112          33
# 34  "These two are among some of the most extreme ...  111111112          35
# 35  They've nothing to contribute to life in this ...  111111112          36
# 37  "They're not here to contribute to good commun...  111111112          38
# 38  They only wanted to come here and help the EDL...  111111112          39
# 39  Britain doesn't need more hate even just for a...  111111112          40
# 41  Mr Spencer put up a copy of what appears to be...  111111112          42
# 43  The letters, both dated Tuesday, claim that bo...  111111112          44
# 45  Both letters gave examples of anti-Muslim view...  111111112          46
#
#      is_propaganda   sadness       joy      fear   disgust     anger
# 0   non-propaganda  0.273694  0.104768  0.121820  0.378717  0.378898

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ed0ac44919ba> in <module>()
# ----> 1 df == df2
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in f(self, other)
#    1324     def f(self, other):
#    1325         if isinstance(other, ABCDataFrame):  # Another DataFrame
# -> 1326             return self._compare_frame(other, func, str_rep)
#    1327         elif isinstance(other, ABCSeries):
#    1328             return self._combine_series_infer(other, func, try_cast=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _compare_frame(self, other, func, str_rep, try_cast)
#    4015     def _compare_frame(self, other, func, str_rep, try_cast=True):
#    4016         if not self._indexed_same(other):
# -> 4017             raise ValueError('Can only compare identically-labeled '
#    4018                              'DataFrame objects')
#    4019         return self._compare_frame_evaluate(other, func, str_rep,
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
df2.shape
# Out:
# (14263, 9)

# %%
df.shape
# Out:
# (14263, 9)

# %%
df.dtypes
# Out:
# sentences         object
# article            int64
# N_sentence         int64
# is_propaganda     object
# sadness          float64
# joy              float64
# fear             float64
# disgust          float64
# anger            float64
# dtype: object

# %%
df2.dtypes
# Out:
# sentences         object
# article            int64
# N_sentence         int64
# is_propaganda     object
# sadness          float64
# joy              float64
# fear             float64
# disgust          float64
# anger            float64
# dtype: object

# %%
df_text = df['sentences']

# %%
df_text.head()
# Out:
# 0    New Audio From The Night Of The Las Vegas Mass...
# 2    Newly released audio from the Clark County Fir...
# 3    The audio, released on the SoundCloud account ...
# 4    Intellihub’s Shepard Ambellas, who has extensi...
# 5    “We have a firefighter’s wife at this event wh...
# Name: sentences, dtype: object

# %%
df[['sentences']]
# Out:
#                                             sentences
# 0   New Audio From The Night Of The Las Vegas Mass...
# 2   Newly released audio from the Clark County Fir...
# 3   The audio, released on the SoundCloud account ...
# 4   Intellihub’s Shepard Ambellas, who has extensi...
# 5   “We have a firefighter’s wife at this event wh...
# 6   We are trying to get further on the name,” dis...
# 7   “Batallion 6, be advised that we are getting r...
# 8   After being asked to confirm the information, ...
# 9   “The only information I have is it’s the bar o...
# 10  Interestingly, the story doesn’t end there, as...
# 11  The popular social media influencer apparently...
# 12  Cardone wrote about his experience in a post o...
# 13  It was reported by the Mandalay there was a sh...
# 14  I told Elena and Johnny, “stay close to me, we...
# 15  Then twitter started showing up with feeds sug...
# 16  This new report documenting yet another instan...
# 17  “During the air traffic control recordings, wh...
# 18  “Shutting down might not be a good idea, there...
# 19  “The 19s are closed, we are in the process of ...
# 20  Air traffic control tapes on the night of the ...
# 21  They’re on the airport property” pic.twitter.c...
# 22  Slowly but surely we are beginning to see the ...
# 23  Sadly, the picture emerging is one that includ...
# 0            Archbishop Hebda and McCarrick's Scandal
# 2   Archbishop Bernard Hebda of St. Paul, MN, resp...
# 3   Every time Mass is celebrated, the priest pray...
# 4   I’ve been praying that prayer even more earnes...
# 5   To make matters worse (if that is even possibl...
# 6   While I realize that it is not always easy to ...
# 7   The matter has been particularly troubling to ...
# ..                                                ...
# 19  As a result, the judge imposed significantly l...
# 20  The previous administration, however, filed an...
# 21                                   This was unjust.
# 22  Dwight Hammond is now 76 years old and has ser...
# 23  Steven Hammond is 49 and has served approximat...
# 24  They have also paid $400,000 to the United Sta...
# 25  The Hammonds are devoted family men, respected...
# 26  Justice is overdue for Dwight and Steven Hammo...
# 27  Well, it took long enough, but thank you Presi...
# 28            You did the right thing in this matter.
# 29  And for all those who took the time to keep th...
# 30  It should be noted that the protests that took...
# 31  As a result, Robert "LaVoy" Finicum was killed...
# 32  Those who led the protest were all acquitted o...
# 33  No doubt, Finicum would have been found not gu...
# 34  Today is a day to celebrate a wrong that has n...
# 35  Article posted with permission from The Washin...
# 0   Ebola outbreak declared in Democratic Republic...
# 2   Story highlights Two cases were confirmed, pro...
# 3   In the past five weeks, there have been 21 sus...
# 4   (CNN) The government of the Democratic Republi...
# 5   The declaration came after laboratory results ...
# 6   Ebola virus disease, which most commonly affec...
# 7   The virus is transmitted to people from wild a...
# 8       The average case fatality rate is around 50%.
# 9   A government statement released Tuesday states...
# 10  In the past five weeks, there have been 21 sus...
# 11  "We will gather more samples, conduct contact ...
# 12  "WHO will work closely with health authorities...
# 13                                          Read More
#
# [14263 rows x 1 columns]

# %%
df.to_pickle('/content/gdrive/My Drive/datathon/task2data.pkl')

# %%
df3 = pd.read_pickle('/content/gdrive/My Drive/datathon/task2data.pkl')

# %%
df.equals(df3)
# Out:
# True

# %%
df.head(1000)
# Out:
#                                             sentences    article  N_sentence  \
# 0   New Audio From The Night Of The Las Vegas Mass...  704856340           1
# 2   Newly released audio from the Clark County Fir...  704856340           3
# 3   The audio, released on the SoundCloud account ...  704856340           4
# 4   Intellihub’s Shepard Ambellas, who has extensi...  704856340           5
# 5   “We have a firefighter’s wife at this event wh...  704856340           6
# 6   We are trying to get further on the name,” dis...  704856340           7
# 7   “Batallion 6, be advised that we are getting r...  704856340           8
# 8   After being asked to confirm the information, ...  704856340           9
# 9   “The only information I have is it’s the bar o...  704856340          10
# 10  Interestingly, the story doesn’t end there, as...  704856340          11
# 11  The popular social media influencer apparently...  704856340          12
# 12  Cardone wrote about his experience in a post o...  704856340          13
# 13  It was reported by the Mandalay there was a sh...  704856340          14
# 14  I told Elena and Johnny, “stay close to me, we...  704856340          15
# 15  Then twitter started showing up with feeds sug...  704856340          16
# 16  This new report documenting yet another instan...  704856340          17
# 17  “During the air traffic control recordings, wh...  704856340          18
# 18  “Shutting down might not be a good idea, there...  704856340          19
# 19  “The 19s are closed, we are in the process of ...  704856340          20
# 20  Air traffic control tapes on the night of the ...  704856340          21
# 21  They’re on the airport property” pic.twitter.c...  704856340          22
# 22  Slowly but surely we are beginning to see the ...  704856340          23
# 23  Sadly, the picture emerging is one that includ...  704856340          24
# 0            Archbishop Hebda and McCarrick's Scandal  778664280           1
# 2   Archbishop Bernard Hebda of St. Paul, MN, resp...  778664280           3
# 3   Every time Mass is celebrated, the priest pray...  778664280           4
# 4   I’ve been praying that prayer even more earnes...  778664280           5
# 5   To make matters worse (if that is even possibl...  778664280           6
# 6   While I realize that it is not always easy to ...  778664280           7
# 7   The matter has been particularly troubling to ...  778664280           8
# ..                                                ...        ...         ...
# 4                                   Fox News reports:  761897089           5
# 5   take our poll - story continues below Whom do ...  761897089           6
# 3   The audio, released on the SoundCloud account ...   704856340           4
# 4   Intellihub’s Shepard Ambellas, who has extensi...   704856340           5
# 5   “We have a firefighter’s wife at this event wh...   704856340           6
# 6   We are trying to get further on the name,” dis...   704856340           7
# 7   “Batallion 6, be advised that we are getting r...   704856340           8
# 8   After being asked to confirm the information, ...   704856340           9
# 9   “The only information I have is it’s the bar o...   704856340          10
# 10  Interestingly, the story doesn’t end there, as...   704856340          11
# 11  The popular social media influencer apparently...   704856340          12
# 12  Cardone wrote about his experience in a post o...   704856340          13
# 13  It was reported by the Mandalay there was a sh...   704856340          14
# 14  I told Elena and Johnny, “stay close to me, we...   704856340          15
# 15  Then twitter started showing up with feeds sug...   704856340          16
# 16  This new report documenting yet another instan...   704856340          17
# 17  “During the air traffic control recordings, wh...   704856340          18
# 18  “Shutting down might not be a good idea, there...   704856340          19
# 19  “The 19s are closed, we are in the process of ...   704856340          20
# 20  Air traffic control tapes on the night of the ...   704856340          21
# 21  They’re on the airport property” pic.twitter.c...   704856340          22
# 0            Archbishop Hebda and McCarrick's Scandal   778664280           1
# 2   Archbishop Bernard Hebda of St. Paul, MN, resp...   778664280           3
# 3   Every time Mass is celebrated, the priest pray...   778664280           4
# 4   I’ve been praying that prayer even more earnes...   778664280           5
# 6   While I realize that it is not always easy to ...   778664280           7
# 7   The matter has been particularly troubling to ...   778664280           8
# 8   It was while I was in Newark that I was introd...   778664280           9
# 9   A number of good Catholics have written to ask...   778664280          10
# 10  I can state unequivocally that I learned of th...   778664280          11
# ..                                                ...         ...         ...
# 14  Name This field is for validation purposes and...  7709564349          15
# 15  Completing this poll grants you access to Free...  7709564349          16
# 16                        You may opt out at anytime.  7709564349          17
# 17  You also agree to this site's Privacy Policy a...  7709564349          18
# 19  As a result, the judge imposed significantly l...  7709564349          20
# 21                                   This was unjust.  7709564349          22
# 22  Dwight Hammond is now 76 years old and has ser...  7709564349          23
# 23  Steven Hammond is 49 and has served approximat...  7709564349          24
# 24  They have also paid $400,000 to the United Sta...  7709564349          25
# 26  Justice is overdue for Dwight and Steven Hammo...  7709564349          27
# 27  Well, it took long enough, but thank you Presi...  7709564349          28
# 28            You did the right thing in this matter.  7709564349          29
# 29  And for all those who took the time to keep th...  7709564349          30
# 30  It should be noted that the protests that took...  7709564349          31
# 31  As a result, Robert "LaVoy" Finicum was killed...  7709564349          32
# 32  Those who led the protest were all acquitted o...  7709564349          33
# 34  Today is a day to celebrate a wrong that has n...  7709564349          35
# 35  Article posted with permission from The Washin...  7709564349          36
# 0   Ebola outbreak declared in Democratic Republic...   754131438           1
# 2   Story highlights Two cases were confirmed, pro...   754131438           3
# 3   In the past five weeks, there have been 21 sus...   754131438           4
# 5   The declaration came after laboratory results ...   754131438           6
# 6   Ebola virus disease, which most commonly affec...   754131438           7
# 7   The virus is transmitted to people from wild a...   754131438           8
# 8       The average case fatality rate is around 50%.   754131438           9
# 9   A government statement released Tuesday states...   754131438          10
# 10  In the past five weeks, there have been 21 sus...   754131438          11
# 11  "We will gather more samples, conduct contact ...   754131438          12
# 12  "WHO will work closely with health authorities...   754131438          13
# 13                                          Read More   754131438          14
# 28  non-propaganda  0.090506  0.458983  0.061501  0.070417  0.153366       0
# 29  non-propaganda  0.028404  0.771429  0.044028  0.089192  0.090892       0
# 30  non-propaganda  0.407845  0.148792  0.077867  0.288603  0.259640       0
# 31  non-propaganda  0.292306  0.026000  0.344638  0.289816  0.361166       0
# 32  non-propaganda  0.189109  0.018164  0.080272  0.390024  0.478058       0
# 34  non-propaganda  0.198788  0.666205  0.038520  0.065421  0.064158       0
# 35  non-propaganda  0.200295  0.219086  0.045240  0.144069  0.114482       0
# 0   non-propaganda  0.191436  0.049868  0.497076  0.163518  0.069410       0
# 2   non-propaganda  0.159647  0.333292  0.052588  0.078243  0.044540       0
# 3   non-propaganda  0.509654  0.005811  0.326232  0.074272  0.229038       0
# 5   non-propaganda  0.099817  0.743531  0.044588  0.012416  0.018162       0
# 6   non-propaganda  0.336926  0.007877  0.717959  0.079862  0.077826       0
# 7   non-propaganda  0.206064  0.138941  0.124028  0.530860  0.075682       0
# 8   non-propaganda  0.097424  0.041395  0.219216  0.031306  0.109334       0
# 9   non-propaganda  0.359534  0.053110  0.509508  0.204923  0.074524       0
# 10  non-propaganda  0.445606  0.004275  0.328817  0.060647  0.140445       0
# 11  non-propaganda  0.095306  0.347390  0.038749  0.027966  0.128703       0
# 12  non-propaganda  0.246274  0.485863  0.093077  0.041907  0.046538       0
# 13  non-propaganda  0.000000  0.000000  0.000000  0.000000  0.000000       0
#
# [10325 rows x 10 columns]

# %% [markdown]
# 3938 propaganda, 10325 non-propaganda

# %%
df.loc[df['article'] == 111111112]

# %%
df['target'] = df['is_propaganda'].map({'propaganda': 1, 'non-propaganda': 0})

# %%
text_only_df = df[['sentences','target']]

# %%
text_only_df.head(20)
# Out:
#                                             sentences  target
# 0   New Audio From The Night Of The Las Vegas Mass...       0
# 2   Newly released audio from the Clark County Fir...       0
# 3   The audio, released on the SoundCloud account ...       0
# 4   Intellihub’s Shepard Ambellas, who has extensi...       0
# 5   “We have a firefighter’s wife at this event wh...       0
# 6   We are trying to get further on the name,” dis...       0
# 7   “Batallion 6, be advised that we are getting r...       0
# 8   After being asked to confirm the information, ...       0
# 9   “The only information I have is it’s the bar o...       0
# 10  Interestingly, the story doesn’t end there, as...       0
# 11  The popular social media influencer apparently...       0
# 12  Cardone wrote about his experience in a post o...       0
# 13  It was reported by the Mandalay there was a sh...       0
# 14  I told Elena and Johnny, “stay close to me, we...       0
# 15  Then twitter started showing up with feeds sug...       0
# 16  This new report documenting yet another instan...       0
# 17  “During the air traffic control recordings, wh...       0
# 18  “Shutting down might not be a good idea, there...       0
# 19  “The 19s are closed, we are in the process of ...       0
# 20  Air traffic control tapes on the night of the ...       0

# %%
SEED = 666

y = df[['target']]

X_train, X_test, y_train, y_test = train_test_split(
        df, y,stratify=y, test_size=0.2, random_state=SEED)

# %%
X_val, X_test_real, y_val, y_test_real = train_test_split(
        X_test, y_test,stratify=y_test, test_size=0.5, random_state=SEED)

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.model_selection import GridSearchCV


vectorizer = TfidfVectorizer(min_df = 3, max_df=0.5,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3), use_idf=1,smooth_idf=1,sublinear_tf=1,
            stop_words = 'english')

# %%
X_train.head()
# Out:
#                                             sentences    article  N_sentence  \
# 31  The Nuncio added that Littleton had already fo...  782086447          32
# 21  FACT asked the Senate ethics committee to prob...  999000147          22
# 8   “There is a silence among many who call themse...  763260610           9
# 42  The President of AMANA, Sofian Zakkout, has re...  728169864          43
# 81                             Date of erection: 1994  761334950          82
#
#      is_propaganda   sadness       joy      fear   disgust     anger  target
# 31  non-propaganda  0.299419  0.027867  0.243245  0.177422  0.064517       0
# 21  non-propaganda  0.389350  0.018483  0.065846  0.362440  0.294696       0
# 8   non-propaganda  0.688505  0.061684  0.211507  0.057255  0.112880       0
# 42      propaganda  0.063294  0.450346  0.035087  0.310004  0.138506       1
# 81  non-propaganda  0.044200  0.195751  0.011521  0.159430  0.030789       0

# %%
x_train = vectorizer.fit_transform(X_train['sentences'])

# %%
x_train.shape
# Out:
# (11410, 12193)

# %%
type(x_train)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from scipy.sparse import hstack
model = LinearSVC(C=1.0, class_weight='balanced', multi_class='ovr', random_state=SEED)
model.fit(hstack([x_train, X_train[['sadness', 'joy', 'fear', 'disgust' , 'anger']].values]), y_train.values.ravel())
# Out:
# LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=666, tol=0.0001,
#      verbose=0)

# %%
X_train[['sadness', 'joy', 'fear', 'disgust' , 'anger']].values.shape
# Out:
# (11410, 5)

# %%
y_train_predict = model.predict(hstack([x_train, X_train[['sadness', 'joy', 'fear', 'disgust' , 'anger']].values]))

# %%
from sklearn.metrics import classification_report

print(classification_report(y_train.values.ravel(), y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      8260
#            1       0.84      0.97      0.90      3150
#
#    micro avg       0.94      0.94      0.94     11410
#    macro avg       0.91      0.95      0.93     11410
# weighted avg       0.95      0.94      0.94     11410

# %%
from sklearn.metrics import classification_report

print(classification_report(y_train.values.ravel(), y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      8260
#            1       0.84      0.97      0.90      3150
#
#    micro avg       0.94      0.94      0.94     11410
#    macro avg       0.91      0.95      0.93     11410
# weighted avg       0.95      0.94      0.94     11410

# %%
x_val = vectorizer.transform(X_val['sentences'])

# %%
y_val_predict = model.predict(X_val[['sadness', 'joy', 'fear', 'disgust' , 'anger']].values)

# %%
print(classification_report(y_val.values.ravel(), y_val_predict))
# tf idf only
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      1032
#            1       0.47      0.54      0.51       394
#
#    micro avg       0.71      0.71      0.71      1426
#    macro avg       0.64      0.66      0.65      1426
# weighted avg       0.72      0.71      0.71      1426

# %%
print(classification_report(y_val.values.ravel(), y_val_predict))
# tf idf with emotions
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      1032
#            1       0.48      0.55      0.51       394
#
#    micro avg       0.71      0.71      0.71      1426
#    macro avg       0.65      0.66      0.65      1426
# weighted avg       0.72      0.71      0.72      1426

# %%
print(classification_report(y_val.values.ravel(), y_val_predict))
# emotions only
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.58      0.68      1032
#            1       0.37      0.66      0.48       394
#
#    micro avg       0.60      0.60      0.60      1426
#    macro avg       0.60      0.62      0.58      1426
# weighted avg       0.69      0.60      0.62      1426

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# %%
print('aa')
# Out:
# aa

# %%
model = PassiveAggressiveClassifier(C=1.0, class_weight='balanced', multi_class='ovr', random_state=40)
model.fit(hstack([x_train, X_train[['sadness', 'joy', 'fear', 'disgust' , 'anger']].values]), y_train.values.ravel())
